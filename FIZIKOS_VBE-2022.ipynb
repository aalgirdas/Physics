# %% [markdown]
# [fizikos valstybinio brandos egzamino užduotis](https://www.nsa.smm.lt/wp-content/uploads/2022/06/FIZIKOS_VBE-1-2022.pdf)
#
# [egzamino užduoties priedas](https://www.nsa.smm.lt/wp-content/uploads/2022/06/FIZIKOS_VBE-1-2022_PRIEDAS.pdf)
#
#
# [atsakymai](https://www.lrt.lt/naujienos/lietuvoje/2/1721670/abiturientai-laikys-fizikos-egzamina)

# %% [markdown]
# >>![Untitled.png](data:image/png;base64,...)

# %% [markdown]
# > **Atsakymas**  **D**
#
# <hr>
#
# &#x0001f600; <font size="2"> Pateikus šią užduotį dirbtinio intelekto sistemai ChatGPT buvo gautas atsakymas: <i><b> D Lėktuvą veikiančių jėgų atstojamoji lygi nuliui.</b></i> </font> &#x0001F44D;
#
# <font size="2">Paklausus kodėl buvo gautas atsakymas: <i><b>Lėktuvą skrendant tolygiai, jėgos, veikiančios lėktuvą, yra lygios ir atvirkščiai veikiančios, o tai reiškia, kad jų atstojamoji lygus nuliui. Tai reiškia, kad lėktuvas yra statiškai pusiausvyro būsenoje. Variklio traukos jėga skrenda lėktuvą, o sunkio jėga krenta žemyn. Šios jėgos yra lygios ir atvirkščiai veikiančios, todėl jų atstojamoji lygi nuliui, taigi lėktuvas išlieka tolygiai skrendantis.</b></i> </font> &#x0001F44D;
#
# <br/>
#
# ***Papildomai***
#
# [Lėktuvo valdymo simuliacija](https://youtu.be/Km9k2BbxMOA)
#
#
#
# <br/><br/><br/><br/>

# %% [markdown]
# >>![Untitled.png](data:image/png;base64,...)

# %% [markdown]
# > **Atsakymas**  **B**
#
# <hr>
#
# &#x0001f600; <font size="2">  Pateikus šią užduotį dirbtinio intelekto sistemai ChatGPT buvo gautas atsakymas: <i><b> IV fizikinio dydžio matavimo vertė (švytuoklės svyravimo periodas) Mėnulyje ir Žemėje sutaps, nes šis matavimas priklauso tik nuo laiko, o laiko pasiskirstymas Mėnulyje ir Žemėje yra vienodas.</b></i> </font> &#x0001F44E;
#
# <font size="2">Paklausus Ar tikrai ne II. variantas?: <i><b>Aš klydau. IV fizikinio dydžio matavimo vertė (švytuoklės svyravimo periodas) Mėnulyje ir Žemėje nebus sutapusi, nes šio matavimo vertė priklauso ne tik nuo laiko, bet ir nuo gravitacinio lauko stiprumo. Gravitacinio lauko stiprumas Mėnulyje yra mažesnis nei Žemėje, todėl švytuoklės svyravimo periodas bus ilgesnis nei Žemėje.</b></i> </font> &#x0001F44D;
#
#
# <font size="2">Tai tada kuris atsakymas: <i><b>I fizikinio dydžio matavimo vertė (kūno svoris) Mėnulyje ir Žemėje sutaps, nes svoris yra masės dydis ir masė yra pastovi vertė, o gravitacinio lauko stiprumas Mėnulyje ir Žemėje skiriasi.</b></i> </font> &#x0001F44E;
#
# <font size="2">Ar tikrai ne II. variantas? <i><b>Atsiprašau, aš dar kartą klydau. II fizikinio dydžio matavimo vertė (kūno masė) Mėnulyje ir Žemėje sutaps, nes masė yra pastovi vertė ir nepriklauso nuo vietos, kurioje ji yra matuojama.</b></i> </font> &#x0001F44D;
#
# <br/><br/><br/><br/>

# %% [markdown]
# >>![Untitled.png](data:image/png;base64,...)

# %% [markdown]
# > **Atsakymas**  **B**
#
# <hr>
#
# &#x0001f600; <font size="2"> Iš ChatGPT buvo gautas atsakymas: <i><b>Naudingasis darbas, kurį siurblys atliks per 300 s, bus 1000 W * 300 s = 300 000 J (vienetai: W * s = J).</b></i> </font> &#x0001F44D;
#
#
# <font size="2"> Nutariau pameluoti iš įvedžiau: Aš klausiau apie naudingumo koeficientą  <i><b>Atsiprašau, jei klydau. Jei siurblio naudingumo koeficientas yra 40%, tai reiškia, kad 40% energijos, kurią jis suvartoja, bus naudinga, o likusi dalis bus nevykdoma arba šiluma. Taigi naudingasis darbas, kurį siurblys atliks per 300 s, bus 2500 W * 0.4 * 300 s = 300 000 J (vienetai: W * s = J).</b></i> </font> &#x0001F44D;
#
# <br/><br/><br/><br/>

# %% [markdown]
# ![Untitled.png](data:image/png;base64,...)

# %% [markdown]
# > Skysčio slėgis $p=\rho g h$. Tad atsakymas C.
#
# > **Atsakymas**  **C**
#
# <hr>
#
# &#x0001f600; <font size="2"> Kadangi ChatGPT paveikslų nepriima tai buvo paduotas toks uždavinys: <i><b>Inde ir jame plūduriuojančiame plonasieniame cilindre gali būti arba žibalas, arba vanduo (cilindre skysčio lygis auksčiau nei inde). Kuris skystis yra inde, kuris – cilindre? Vandens tankis 1000 kg/m3 , o žibalo tankis 800 kg/m3.</b></i> </font>
#
#
# <font size="2"> Gautas atsakymas  <i><b>Skystis, esantis inde, yra žibalo, o cilindre - vanduo.</b></i> </font> &#x0001F44E;
#
# <br/><br/><br/><br/>

# %% [markdown]
# >>![Untitled.png](data:image/png;base64,...)

# %% [markdown]
# > **Atsakymas**  **D**
#
# <hr>
#
# &#x0001f600; <font size="2">Kadangi ChatGPT paveikslų nepriima tai buvo paduotas toks uždavinys: <i><b> Kūnas pradėjo judėti, veikiamas vienintelės pastovios jėgos. Kokia kūno įgytos kinetinės energijos priklausomybė nuo kūną veikiančios jėgos atlikto darbo?</b></i> </font>
#
#
# <font size="2"> Gautas atsakymas  <i><b>Kūno įgytos kinetinės energijos priklausomybė nuo kūną veikiančios jėgos atlikto darbo yra darbo-energijos teorema, kuri sako, kad darbas, atliktas kūnu, yra lygi kūno kinetinei energijai (W = ΔK). Tai reiškia, kad kiekvienas kartą, kai jėga veikia kūną, ji padidina jo kinetinę energiją proporcingai atlikto darbo kiekiui.</b></i> </font> &#x0001F44D;
#
# <br/><br/><br/><br/>

# %% [markdown]
# >>![Untitled.png](data:image/png;base64,...)

# %% [markdown]
# > **Atsakymas**  **B**
#
# <hr>
#
# &#x0001f600; <font size="2">Kadangi ChatGPT paveikslų nepriima tai buvo paduotas toks uždavinys: <i><b> Šlifavimo diskas, kurio spindulys 0,15 m. Besisukančio disko darbinio paviršiaus taškų įcentrinis pagreitis lygus 60. Kam lygus disko sukimosi kampinis greitis?</b></i> </font>
#
#
# <font size="2"> Gautas atsakymas  <i><b>Dėl centrinio pagreičio-kutinio greičio dėsnio ω = α * r kur α yra įcentrinis pagreitis, r yra spindulio ilgis. Taigi
# ω = 60 m/s^2 * 0,15m = 9 rad/s Sukimosi kampinis greitis (ω) lygus 9 rad/s.</b></i> </font> &#x0001F44E;
#
# <br/><br/><br/><br/>

# %% [markdown]
# >>![Untitled.png](data:image/png;base64,...)

# %% [markdown]
# > **Atsakymas**  **C**
#
# <hr>
#
# &#x0001f600; <font size="2">Kadangi ChatGPT paveikslų nepriima tai klausimas nebuvo užduotas</b></i> </font>
#
#
# <br/><br/><br/><br/>

# %% [markdown]
# >>![Untitled.png](data:image/png;base64,...)

# %% [markdown]
# $p \cdot V = n \cdot R \cdot T$
#
# Tai $n  = \frac{p \cdot V}{R \cdot T}  = \frac{5 \cdot 10^5 \cdot 5 \cdot 10^{-3}}{8.314 \cdot 800} \approx 0.375 \approx 0.4 $
#
# **Atsakymas B**
#
#
# <hr>
#
#
# <b><font color='blue'>Klausimas kurį uždavėm ChatGPT </font></b>
#
# > *Kaitinant idealiąsias dujas 0.005 kūbinių metrų tūrio metaliniame inde, gauta temperatūra 800 K , o slėgis 500000.
# Apskaičiuokite, kam apytiksliai lygus inde kaitinamų dujų medžiagos kiekis.*
#
#
# <b><font color='green'>Atsakymas</font></b>
#
# >Norint apskaičiuoti kaitinamų dujų medžiagos kiekį, reikia naudoti PV = nRT formulę, kur P yra slėgis, V yra tūris, n yra medžiagos kiekis (molių skaičius), R yra universalus dujų konstanta (apie 8.314 J / mol · K) ir T yra temperatūra (Kelvin).
# Vartojant šias reikšmes, medžiagos kiekis n bus:
# n = (P * V) / (R * T)
# n = (500000 Pa * 0.005 m³) / (8.314 J / mol · K * 800 K) 😀
# <font color='red'>n ≈ 11.69 mol
# Taigi, kaitinamų dujų medžiagos kiekis yra apie 11.69 mol.</font>  😞
#
#
#
# <br/><br/><br/><br/>

# %% [markdown]
# >>![Untitled.png](data:image/png;base64,...)

# %% [markdown]
# **Atsakymas A**
#
#
# <hr>
#
#
# <b><font color='blue'>Klausimas kurį uždavėm ChatGPT (geriau angliškai nes tada mažiau klaidų)</font></b>
#
# > *What is the amount of work done by an ideal gas when it changes from a state with a volume of 0.1 m^3 to a state with a volume of 0.2 m^3 and when the pressure does not change and is equal to 100000 Pa*
#
#
# <b><font color='green'>Atsakymas</font></b>
#
# >The work done by an ideal gas is given by W = PΔV, where P is the pressure and ΔV is the change in volume. If the pressure does not change, then W = PΔV = 100000 Pa * (0.2 m^3 - 0.1 m^3) = 10000 J. 😀
#
#
#
# <b><font color='blue'>Klausimas kurį uždavėm ChatGPT</font></b>
#
# > *What magnitude of work is done by an ideal gas from a state with a pressure of 100000 Pa to a state with a pressure of 300000 Pa and when the volume does not change and is equal to 0.2 m^3*
#
#
# <b><font color='green'>Atsakymas</font></b>
#
# >The work done by an ideal gas in a process where the volume stays constant (isochoric process) is equal to zero. Therefore, the magnitude of work done in this scenario is 0 J.😀
#
#
#
# <br/><br/><br/><br/>

# %% [markdown]
# #10.
#
# Mokiniai matavo vandens pakilimo kapiliariniais vamzdeliais aukštį, naudodamiesi skirtingo skersmens vamzdelių rinkiniu. Gautus rezultatus pavaizdavę grafiku, mokiniai įsitikino, kad vandens pakilimo kapiliariniu vamzdeliu aukščio priklausomybė nuo vamzdelio vidinio skersmens
# yra:
# A tiesė;
# B parabolė;
# C hiperbolė;
# D apskritimo lankas.

# %% [markdown]
# **Atsakymas C**
#
#
# <hr>
#
#
# <b><font color='blue'>Klausimas kurį uždavėm ChatGPT (angliškai išvesta su Google Translate)</font></b>
#
# > *Students measured the height of water rising in capillary tubes using a set of tubes of different diameters. After showing the obtained results in a graph, the students were convinced that the dependence of the height of water rising through a capillary tube on the inner diameter of the tube is:
# A line
# B parabola
# C hyperbola
# D circle arc*
#
#
# <b><font color='green'>Atsakymas</font></b>
#
# >The dependence of the height of water rising through a capillary tube on the inner diameter of the tube is typically modeled as a curve, not a line or a simple geometric shape. However, the exact form of the curve can depend on several factors, such as the properties of the liquid and the tube material.
#
# In some cases, the curve may be well-approximated by a parabolic shape, while in other cases it may be closer to a hyperbolic shape. It is unlikely that the dependence would be modeled as a simple circle arc. 😀
#
#
#
# <b><font color='blue'>Klausimas kurį uždavėm ChatGPT</font></b>
#
# > *give me simple mathematical expresion*
#
#
# <b><font color='green'>Atsakymas</font></b>
#
# >The height of water rising in a capillary tube can be modeled by the equation:
# h = 2 * γ * cos(θ) / ρ * g * r,
# where h is the height of water rise, γ is the surface tension of the liquid, θ is the contact angle between the liquid and the tube material, ρ is the density of the liquid, g is the acceleration due to gravity, and r is the inner radius of the tube.
# This equation is an empirical model and its accuracy can vary depending on the specific conditions being studied.😀
#
#
#
# <br/><br/><br/><br/>

# %% [markdown]
# >>![Untitled.png](data:image/png;base64,...)

# %% [markdown]
# **Atsakymas A**
#
#
# Klausimas angliškai
#
# The graph shows how the strength of the electric current flowing through four different resistors (I, II, III and IV) depends on the voltage. How to determine which resistor has the highest resistance?
#
# Atsakymas angliškai
#
# The resistance of a resistor can be determined by calculating the slope of the line representing its current-voltage relationship on a graph. A steeper slope means a smaller resistance, while a shallower slope represents a higher resistance. Therefore, the resistor with the flattest line has the highest resistance. In the graph provided, resistor IV has the flattest line, indicating it has the highest resistance.
#
#
#
#
# Klausimas lietuviškai
#
# Grafike pavaizduota, kaip keturiais skirtingais rezistoriais (I, II, III ir IV) tekančios elektros srovės stipris priklauso nuo įtampos. Kaip  nustatyti , kurio rezistoriaus varža yra didžiausia ?
#
# Atsakymas lietuviškai
#
# Rezistoriaus varža gali būti nustatoma apskaičiuojant jo srovės-įtampos santykio linijos nuolydį grafike. Staigesnė linija reiškia mažesnę varžą, o plokštesnė linija atspindi didesnę varžą. Todėl plokščiausia linija reiškia didžiausią varžą. Pateiktame grafike rezistorius IV turi plokščiausią liniją, o tai reiškia, kad jo varža yra didžiausia.

# %% [markdown]
# >>![Untitled.png](data:image/png;base64,...)

# %% [markdown]
# **Atsakymas C**
#
#
# The graph shows the power of four electrical devices (I, II, III and IV) and their working time. How do you determine which device did the most work?
#
#
#
# The work done by an electrical device can be determined by finding the area under its power-time curve on the graph. The larger the area, the more work the device has done. Therefore, the device with the greatest area under its power-time curve has done the most work. In the graph provided, it appears that device IV has the greatest area under its power-time curve, indicating that it has done the most work.
#
#
#
#
#
# Grafike pavaizduota keturių elektros prietaisų (I, II, III ir IV) galia ir jų darbo laikas. Kaip nustatyti kuris prietaisas atliko didžiausią darbą?
#
#
#
#
#
# Elektros prietaiso atliktas darbas gali būti nustatomas rasti jo galios-laiko kreivės ploto grafike. Kuo didesnis plotas, tuo daugiau darbo atliko prietaisas. Todėl prietaisas su didžiausiu galios-laiko kreivės ploto atliko didžiausią darbą. Pateiktame grafike atrodo, kad prietaisas IV turi didžiausią galios-laiko kreivės ploto dalį, o tai reiškia, kad jis atliko didžiausią darbą.

# %% [markdown]
# >>![Untitled.png](data:image/png;base64,...)

# %% [markdown]
# Atsakymas C
#
# pastaba: geometrinė suma nėra vectorinė suma, tai yra geometrinės progresijos narių suma
#
#
#
#
# Complete the sentences to make the statement true.
# If electrified point bodies create electric fields at the investigated point in space, then according to the principle of superposition of electric fields, the strength of the representative electric field at that point in space is equal to the strengths of individual electric fields...
#
# A for difference.
# B for arithmetic mean.
# C for algebraic sum.
# D for the geometric sum.
#
# The strength of the representative electric field at that point in space is equal to the algebraic sum of the strengths of individual electric fields. (C)
#
#
#
#
# yirise3377@themesw.com
# electric field is vector
# Yes, the electric field is a vector quantity, meaning it has both magnitude and direction. It represents the force that a charged particle would feel if placed in that field, and its direction is determined by the direction of the force.
#
#
#
#
# yirise3377@themesw.com
# the the answer must be geometric sum
# No, the correct answer is the algebraic sum. The electric field is a vector quantity, so it must be added vectorially. The principle of superposition states that the net electric field at a point in space is equal to the vector sum of all the individual electric fields at that point, which is the algebraic sum. The geometric sum is not applicable in this case.
#
#
#
#
# yirise3377@themesw.com
# what is geometric sum
# The geometric sum is a mathematical term used to describe the result of multiplying two or more quantities together. In other words, it is the product of a set of numbers. For example, if you have two numbers, 4 and 5, their geometric sum would be 20 (4 x 5 = 20). The geometric sum is used in a variety of applications, including in geometry, statistics, and physics. In some cases, it may be used to describe the product of complex numbers or the growth of a population over time.
#
#
#
#
# yirise3377@themesw.com
# Užbaikite sakinį, kad teiginys būtų teisingas.
# Jei tiriamajame erdvės taške įelektrinti taškiniai kūnai sukuria elektrinius laukus , tai pagal elektrinių laukų superpozicijos principą atstojamojo elektrinio lauko stipris tame erdvės taške lygus atskirų elektrinių laukų stiprių...
#
# A skirtumui.
# B aritmetiniam vidurkiui.
# C algebrinei sumai.
# D geometrinei sumai.
# Atstojamojo elektrinio lauko stipris tame erdvės taške lygus atskirų elektrinių laukų stiprybių algebrinei sumai. (C)
#
#
#
#
#
# https://en.wikipedia.org/wiki/Geometric_series
#
# https://www.cuemath.com/algebra/vector-algebra/

# %% [markdown]
# >>![Untitled.png](data:image/png;base64,...)

# %% [markdown]
# **Atsakymas A**
#
#
# Three resistors of equal resistance are connected in different ways. In which case will the resistance between the terminals be greatest?
#
# A. A resistor is connected in series with two others that are connected in parallel
#
# B. Two resistors connected in series, and a third one parallel to them
#
# C. All three are connected in parallel
# The greatest resistance between the terminals will occur when all three resistors are connected in parallel. (C)
#
# When resistors are connected in parallel, the overall resistance of the circuit is equal to the reciprocal of the sum of the reciprocals of the individual resistances. In this case, since the three resistors are of equal resistance, the overall resistance will be equal to one-third of the individual resistance.
#
# When resistors are connected in series, the overall resistance is equal to the sum of the individual resistances. In this case, the resistance between the terminals would be equal to three times the individual resistance.
#
# When a resistor is connected in series with two others that are connected in parallel, the overall resistance would be greater than when all three are connected in parallel, but less than when they are all connected in series.
#
#
# Trys vienodos varžos rezistoriai jungiami skirtingais būdais. Kuriuo atveju varža tarp gnybtų bus didžiausia?
#
# A. Rezistorius  nuosekliai sujungtas su kitais dviem, kurie sujungti lygiaigrečiai
#
# B. Du nuosekliai sujungti rezistoriai , o trečias lygiaigretus jiems
#
# C. Visi trys sujungti lygiaigrečiai
#
# Didžiausia varža tarp gnybtų atsiras, kai visi trys rezistoriai yra sujungti lygiaigrečiai. (C)
#
# Kai rezistoriai yra sujungti lygiaigrečiai, bendrojo įtampos rezistencija yra lygi atvirkščiai sumai atskirų rezistencijų atvirkščių. Šiuo atveju, kadangi trys rezistoriai turi vienodas varžas, bendra varža bus lygi vieno trečdalo atskirų rezistencijų.
#
# Kai rezistoriai yra sujungti nuosekliai, bendra varža yra lygi atskirų rezistencijų sumai. Šiuo atveju tarp gnybtų varža būtų lygi trims kartams atskirų rezistencijų.
#
# Kai rezistorius yra sujungtas nuosekliai su dviem kitais, kurie sujungti lygiaigrečiai, bendra varža būtų didesnė nei visi trys sujungti lygiaigrečiai, bet mažesnė nei visi trys sujungti nuosekliai.

# %% [markdown]
# >>![Untitled.png](data:image/png;base64,...)

# %% [markdown]
# **Atsakymas B**
#
#
#
# Complete the definition.
# Relative magnetic permeability is a physical quantity that shows how many times the magnetic field induction 𝐵 in a homogeneous medium differs from the induction B0 ...
#
# A in the air.
# B in vacuum.
# C in gas.
# D in a heterogeneous medium.
#
# B in vacuum.
#
#
#
#
# yirise3377@themesw.com
# Why
# The relative magnetic permeability is defined as the ratio of magnetic field induction in a material compared to the magnetic field induction in a reference material, which is typically vacuum or air. So, it compares the magnetic field induction in the material being studied to the magnetic field induction in a known reference, which is vacuum or air. Thus, the answer is B in vacuum.
#
#
#
#
# yirise3377@themesw.com
# Užbaikite apibrėžimą.
# Santykinė magnetinė skvarba – tai fizikinis dydis, rodantis, kiek kartų magnetinio lauko indukcija 𝐵 vienalytėje terpėje skiriasi nuo indukcijos B0 ...
#
# A ore.
# B vakuume.
# C dujose.
# D nevienalytėje terpėje.
# B vakuume.

# %% [markdown]
# [fizikos valstybinio brandos egzamino užduotis](https://www.nsa.smm.lt/wp-content/uploads/2022/06/FIZIKOS_VBE-1-2022.pdf)
#
# [egzamino užduoties priedas](https://www.nsa.smm.lt/wp-content/uploads/2022/06/FIZIKOS_VBE-1-2022_PRIEDAS.pdf)
#
#
# [atsakymai](https://www.lrt.lt/naujienos/lietuvoje/2/1721670/abiturientai-laikys-fizikos-egzamina)
